# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df= pd.read_csv('Amazon_Sales.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   month       10 non-null     object
#  1   product_id  10 non-null     int64
#  2   category    10 non-null     object
#  3   sales       10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.head()
# Out:
#         month  product_id     category  sales
# 0  2023-01-31         201  Electronics   1000
# 1  2023-02-28         202     Clothing   1500
# 2  2023-03-31         203        Books    700
# 3  2023-04-30         201  Electronics   1100
# 4  2023-05-31         202     Clothing   1400

# %%
df.describe()
# Out:
#        product_id        sales
# count   10.000000    10.000000
# mean   201.900000  1107.000000
# std      0.875595   316.475381
# min    201.000000   700.000000
# 25%    201.000000   812.500000
# 50%    202.000000  1125.000000
# 75%    202.750000  1350.000000
# max    203.000000  1550.000000

# %%
df.isnull().sum()
# Out:
# month         0
# product_id    0
# category      0
# sales         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['month'] = pd.to_datetime(df['month'])
df['Month'] = df['month'].dt.month_name()
df['Year'] = df['month'].dt.year

# %%
df.head()
# Out:
#        month  product_id     category  sales  year month_name     Month  Year
# 0 2023-01-31         201  Electronics   1000  2023    January   January  2023
# 1 2023-02-28         202     Clothing   1500  2023   February  February  2023
# 2 2023-03-31         203        Books    700  2023      March     March  2023
# 3 2023-04-30         201  Electronics   1100  2023      April     April  2023
# 4 2023-05-31         202     Clothing   1400  2023        May       May  2023

# %%
df.to_csv('amazon_sales.csv', index=False)
